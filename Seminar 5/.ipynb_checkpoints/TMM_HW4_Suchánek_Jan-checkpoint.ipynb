# %% [markdown]
# # Tools for Modern Macroeconometrics: Homework 4
#
# # Jan Suchánek

# %%
library(dplyr)
install.packages("pdfetch")
library(pdfetch)
install.packages("tsbox")
library(tsbox)
install.packages("forecast")
library(forecast)
install.packages("dlm")
library(dlm)
# Out:
#   There is a binary version available but the source version is later:
#         binary source needs_compilation
# pdfetch  0.2.4  0.2.6             FALSE
# installing the source package 'pdfetch'
#   There is a binary version available but the source version is later:
#       binary source needs_compilation
# tsbox  0.2.1  0.3.1             FALSE
# installing the source package 'tsbox'
#   There is a binary version available but the source version is later:
#          binary source needs_compilation
# forecast   8.14   8.16              TRUE
#
#   Binaries will be installed
# Warning message:
# "package 'forecast' is in use and will not be installed"
# package 'dlm' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\jsuch\AppData\Local\Temp\RtmpOevivD\downloaded_packages
# Warning message:
# "package 'dlm' was built under R version 3.6.3"

# %%
cpi <- pdfetch_EUROSTAT("prc_hicp_midx", FREQ="M", UNIT="I15", COICOP = "CP00", GEO="FI")
x <- ts_first_of_period(cpi) # tsbox requires first day of a period in time stamp
cpi_fi <- ts_ts(x)
inflation_mom <- diff(log(cpi_fi) * 100, lag = 1)

options(repr.plot.width = 10, repr.plot.height = 4)

plot.ts(inflation_mom)
# Out:
# plot without title

# %% [markdown]
# # 1) Estimate the local level model and the basic structural model using StructTS function, and make a forecast for 2 years ahead.

# %%
model1 <- StructTS(inflation_mom, type="level")
model1
model2 <- StructTS(inflation_mom, type="trend")
model2



plot(inflation_mom, type = "o", main="Inflation: Local level (red) and local trend (blue) models")
lines(fitted(model1), lty = "dotted", lwd = 3, col = "red") 
lines(tsSmooth(model1), lwd = 4, col = "red")


model2sm <- tsSmooth(model2)
lines(fitted(model2)[,1], lty = "dotted", lwd = 3, col = "blue")
lines(model2sm[,1], lwd = 4, col = "blue")

model1_f <- forecast(model1)
plot(model1_f)


model2_f <- forecast(model2)
plot(model2_f)
# Out:
# Call:
# StructTS(x = inflation_mom, type = "level")
#
# Variances:
#   level  epsilon
#  0.0000   0.1149
# Call:
# StructTS(x = inflation_mom, type = "trend")
#
# Variances:
#     level      slope    epsilon
# 0.0007706  0.0000000  0.1117729
# Plot with title "Inflation: Local level (red) and local trend (blue) models"
# Plot with title "Forecasts from Local level structural model"
# Plot with title "Forecasts from Local linear structural model"

# %%
dlm1 <- function(parm) {
  dlmModPoly(order = 1, dV = exp(parm[1]), dW = exp(parm[2]))
}

# %%
dlm2 <- function(parm) {
  dlmModPoly(order = 2, dV = exp(parm[1]), dW = exp(parm[2:3]))
}
