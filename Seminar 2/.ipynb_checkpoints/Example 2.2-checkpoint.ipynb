# %% [markdown]
# # Seminar 3
# ## Example 2.2: Fitting deterministic trends to UK output
# ### Mills -- Modelling Trends and Cycles in Economic Time Series
# #### Chapter 2. page 19

# %%
#install.packages("OECD")
library(OECD)
library(magrittr)
library(tidyverse)
library(repr)
library(nlme)
library(ggplot2)
#install.packages("tidyverse")
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.8
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::collapse()  masks nlme::collapse()
# ✖ tidyr::extract()   masks magrittr::extract()
# ✖ dplyr::filter()    masks stats::filter()
# ✖ dplyr::lag()       masks stats::lag()
# ✖ purrr::set_names() masks magrittr::set_names()

# %%
install.packages("tidyverse")
# Out:
# also installing the dependencies ‘colorspace’, ‘bit’, ‘ps’, ‘rappdirs’, ‘rematch’, ‘farver’, ‘labeling’, ‘munsell’, ‘RColorBrewer’, ‘viridisLite’, ‘bit64’, ‘prettyunits’, ‘processx’, ‘highr’, ‘yaml’, ‘xfun’, ‘tinytex’, ‘jquerylib’, ‘backports’, ‘generics’, ‘assertthat’, ‘blob’, ‘DBI’, ‘tidyselect’, ‘withr’, ‘data.table’, ‘gargle’, ‘cellranger’, ‘ids’, ‘rematch2’, ‘gtable’, ‘isoband’, ‘scales’, ‘cpp11’, ‘pkgconfig’, ‘clipr’, ‘vroom’, ‘tzdb’, ‘progress’, ‘callr’, ‘fs’, ‘knitr’, ‘rmarkdown’, ‘selectr’, ‘stringi’, ‘broom’, ‘dbplyr’, ‘dplyr’, ‘dtplyr’, ‘forcats’, ‘googledrive’, ‘googlesheets4’, ‘ggplot2’, ‘haven’, ‘hms’, ‘lubridate’, ‘modelr’, ‘purrr’, ‘readr’, ‘readxl’, ‘reprex’, ‘rstudioapi’, ‘rvest’, ‘stringr’, ‘tibble’, ‘tidyr’
# The downloaded binary packages are in
# 	/var/folders/bm/w6ympyb55m92n8f6vlnzdx7w0000gn/T//RtmpyDVHnX/downloaded_packages

# %% [markdown]
# ## Importing the Data

# %%
input=get_dataset("QNA", filter=list("GBR", "B1_GA", "LNBQRSA", "Q"),  start_time = 1995, end_time = 2019)
#QNA - Quarterly National Accounts
#GBR - Great Britain 
# B1_GA: Gross domestic product (output approach)
input %<>% mutate(timeperiod=seq_len(nrow(input)))
input$lngdp = log(as.numeric(input$ObsValue))
input %>% head
# Out:
#   FREQUENCY LOCATION MEASURE ObsValue POWERCODE REFERENCEPERIOD SUBJECT
# 1 Q         GBR      LNBQRSA 342037   6         2019            B1_GA
# 2 Q         GBR      LNBQRSA 343279   6         2019            B1_GA
# 3 Q         GBR      LNBQRSA 346656   6         2019            B1_GA
# 4 Q         GBR      LNBQRSA 347458   6         2019            B1_GA
# 5 Q         GBR      LNBQRSA 349384   6         2019            B1_GA
# 6 Q         GBR      LNBQRSA 350120   6         2019            B1_GA
#   TIME_FORMAT Time    UNIT timeperiod lngdp
# 1 P3M         1995-Q1 GBP  1          12.74267
# 2 P3M         1995-Q2 GBP  2          12.74630
# 3 P3M         1995-Q3 GBP  3          12.75609
# 4 P3M         1995-Q4 GBP  4          12.75840
# 5 P3M         1996-Q1 GBP  5          12.76393
# 6 P3M         1996-Q2 GBP  6          12.76603

# %%
options(repr.plot.width = 10, repr.plot.height = 4)

# %% [markdown]
# ## GLS trend estimation - With Global Linear Trend

# %% [markdown]
# Figure 1 plots the logarithms of annual UK output (Log GDP) from 1995 to 2019, Q2, upon which is superimposed the fitted linear trend ${\hat \mu}_{lin, t} = 11.83 + 0.005114t$, estimated by feasible GLS using a second-order autoregressive error for $\epsilon_t$. It is clear that this linear trend gives a poor representation of the trend in output, for there are long periods in which the fitted trend is either consistently above output.

# %%
fgls <- gls(lngdp ~ timeperiod, correlation=corARMA(p=1, q=0), data=input)
#fgls <- gls(lngdp ~ timeperiod, data=subinput)
summary(fgls)
# Out:
# Generalized least squares fit by REML
#   Model: lngdp ~ timeperiod
#   Data: input
#         AIC       BIC   logLik
#   -729.6684 -719.3285 368.8342
#
# Correlation Structure: AR(1)
#  Formula: ~1
#  Parameter estimate(s):
#       Phi
# 0.9999998
#
# Coefficients:
#                 Value Std.Error  t-value p-value
# (Intercept) 12.737603  8.173160 1.558467  0.1223
# timeperiod   0.005072  0.000551 9.202604  0.0000
#
#  Correlation:
#            (Intr)
# timeperiod -0.003
#
# Standardized residuals:
#           Min            Q1           Med            Q3           Max
# -0.0008855527  0.0007040764  0.0017863905  0.0084442516  0.0116131055
#
# Residual standard error: 8.173159
# Degrees of freedom: 100 total; 98 residual

# %%
ggplot(data=input, mapping = aes(x=timeperiod, y=lngdp)) +
                                                                                geom_line() +
                                                                                geom_line(aes(y=fgls$fitted), col="red")
# Out:
# plot without title

# %% [markdown]
# ## GLS trend estimation -  - Separate Trend

# %% [markdown]
# Figure 2 superimposes on output separate trends with a break at 2008-Q3, i.e., in the notation of (2.11), These were obtained by estimating (2.11) by feasible GLS, which produced the fitted trend (with standard errors in parentheses and  $d_{2t}$ taking the value 0 from 1995 to 2008 and 1 from 2008 to 2019):

# %% [markdown]
# ${\hat \mu}_{lin, t} = 11.59 + 0.0.006585t + 0.558787 d_{2t}    - 0.002719 td_{2t}$
#
#           (1.43)       (0.0007)              ( 0.23)                    (0.001)

# %% [markdown]
#  (2.11)
#  \begin{equation}
#  y_t = \alpha_1 + \beta_1 t + \sum_{i=2}^{m} \alpha_i d_{it}  + \sum_{i=2}^{m}  \delta_i t d_{it} + \epsilon_t
#  \end{equation}

# %%
#210  2007-Q2
#211  2007-Q3
#212  2007-Q4
#213  2008-Q1
#214  2008-Q2
#215  2008-Q3
#216  2008-Q4

cut = 55  

input$T1 <- ifelse(input$timeperiod > cut, 1, 0)


subinput <- subset(input, input$Time >= "1995-Q1")

# %%
fglsT <- gls(lngdp ~ timeperiod + T1 + timeperiod*T1, correlation=corARMA(p=1, q=0), data=subinput)
summary(fglsT)

ggplot(data=subinput,mapping = aes(x=timeperiod, y=lngdp))+
                                                                                geom_line()+
                                                                                geom_line(aes(y=fglsT$fitted), col="red")
# Out:
# Generalized least squares fit by REML
#   Model: lngdp ~ timeperiod + T1 + timeperiod * T1
#   Data: subinput
#         AIC       BIC   logLik
#   -733.7939 -718.4078 372.8969
#
# Correlation Structure: AR(1)
#  Formula: ~1
#  Parameter estimate(s):
#       Phi
# 0.9999954
#
# Coefficients:
#                   Value Std.Error   t-value p-value
# (Intercept)   12.736402 1.5816171  8.052772  0.0000
# timeperiod     0.006275 0.0006501  9.651226  0.0000
# T1             0.091273 0.0541165  1.686604  0.0949
# timeperiod:T1 -0.002104 0.0009703 -2.167965  0.0326
#
#  Correlation:
#               (Intr) timprd T1
# timeperiod    -0.012
# T1             0.000  0.661
# timeperiod:T1  0.000 -0.670 -0.996
#
# Standardized residuals:
#          Min           Q1          Med           Q3          Max
# -0.021678187 -0.005289664  0.003157400  0.021653707  0.027768352
#
# Residual standard error: 1.58161
# Degrees of freedom: 100 total; 96 residual
# plot without title

# %% [markdown]
# ## GLS trend estimation - Segmented Trend

# %% [markdown]
# A closer examination of the data shows that there is not a ‘clean’  break in the series at 2008. Rather, output declines rapidly between 2008 and 2009 before returning to a new trend path. We thus also fitted a segmented linear trend of the form (2.12) with $T_1 = 2008$ and $T_2 = 2009$:

# %% [markdown]
# ${\hat \mu}_{lin, t} = 7.6 +  0.025t -0.020 \phi_{1t}   -0.01766  \phi_{2t}$

# %% [markdown]
# (2.12)
#
# \begin{equation}
#  y_t = \alpha_1 + \beta_1 t +  \sum_{i=2}^{m}  \delta_i \phi_{it} + \epsilon_t
# \end{equation}
#
# where:\\
#
# (2.13)
#
# \begin{equation}
# \phi_{it} = d_{it}(t - T_{i-1}) =  \left\{ \begin{array}{rcl} t - T_{i-1},  & t > T_{i-1} \\ 0, & otherwise
# \end{array}\right.
# \end{equation}

# %%
start = 53    #2008-Q1
end = 58     #2009-Q2

input$T_start <- ifelse(input$timeperiod > start, start, 0) #Boom
input$T_end <-  ifelse(input$timeperiod > end, 0, end)   #Bust

input$d_1     <-  ifelse(input$timeperiod > start, 1, 0)      #Boom
input$d_2     <-  ifelse(input$timeperiod > end, 0, 1)       #Bust

input$phi_1 = input$d_1 *(input$timeperiod - input$T_start)
input$phi_2 = input$d_2 *(input$timeperiod - input$T_end)
subinput <- subset(input, input$Time >= "1995-Q1")

fglsT <- gls(lngdp ~ timeperiod + phi_1 + phi_2, correlation=corARMA(p=1, q=0), data=subinput)
summary(fglsT)

ggplot(data=subinput,mapping = aes(x=timeperiod, y=lngdp))+
  geom_line()+
  geom_line(aes(y=fglsT$fitted), col="red")
# Out:
# Generalized least squares fit by REML
#   Model: lngdp ~ timeperiod + phi_1 + phi_2
#   Data: subinput
#         AIC       BIC   logLik
#   -784.0833 -768.6972 398.0416
#
# Correlation Structure: AR(1)
#  Formula: ~1
#  Parameter estimate(s):
#       Phi
# 0.9999858
#
# Coefficients:
#                 Value Std.Error    t-value p-value
# (Intercept) 11.743932 0.6926355  16.955428       0
# timeperiod   0.023993 0.0017983  13.341780       0
# phi_1       -0.019115 0.0017080 -11.191658       0
# phi_2       -0.017101 0.0017257  -9.909504       0
#
#  Correlation:
#            (Intr) timprd phi_1
# timeperiod -0.144
# phi_1       0.131 -0.950
# phi_2       0.145 -0.960  0.903
#
# Standardized residuals:
#           Min            Q1           Med            Q3           Max
# -1.821802e-02 -7.416673e-06  1.119928e-02  2.108627e-02  4.582051e-02
#
# Residual standard error: 0.6853557
# Degrees of freedom: 100 total; 96 residual
# plot without title

# %%
input=get_dataset("QNA", filter=list("GBR", "B1_GA", "LNBQRSA", "Q"),  start_time = 1995, end_time = 2020)
input %<>% mutate(timeperiod=seq_len(nrow(input)))
input$lngdp = log(as.numeric(input$ObsValue))

start = 53    #2008-Q1
end = 58     #2009-Q2
big = 59
low = 100 


input$T_start <- ifelse(input$timeperiod > start, start, 0) #Boom
input$T_end <-  ifelse(input$timeperiod > end, 0, end)   #Bust

input$T_big <- ifelse(input$timeperiod > big, big, 0) #Boom
input$T_low  <-  ifelse(input$timeperiod > low , 0, low )   #Bust


input$d_1     <-  ifelse(input$timeperiod > start, 1, 0)      #Boom
input$d_2     <-  ifelse(input$timeperiod > end, 0, 1)       #Bust
input$h_1     <-  ifelse(input$timeperiod > big, 1, 0)      #Boom
input$h_2     <-  ifelse(input$timeperiod > low, 0, 1)       #Bust
input$phi_1 = input$d_1 *(input$timeperiod - input$T_start)
input$phi_2 = input$d_2 *(input$timeperiod - input$T_end)
input$phi_3 = input$h_1 *(input$timeperiod - input$T_big)
input$phi_4 = input$h_2 *(input$timeperiod - input$T_low)
subinput <- subset(input, input$Time >= "1995-Q1")

fglsT <- gls(lngdp ~ timeperiod + phi_1 + phi_2 + phi_3 + phi_4, correlation=corARMA(p=1, q=0), data=subinput)
summary(fglsT)

ggplot(data=subinput,mapping = aes(x=timeperiod, y=lngdp))+
  geom_line()+
  geom_line(aes(y=fglsT$fitted), col="red")
# Out:
# Generalized least squares fit by REML
#   Model: lngdp ~ timeperiod + phi_1 + phi_2 + phi_3 + phi_4
#   Data: subinput
#         AIC       BIC   logLik
#   -431.2802 -410.6004 223.6401
#
# Correlation Structure: AR(1)
#  Formula: ~1
#  Parameter estimate(s):
#       Phi
# 0.1652833
#
# Coefficients:
#                 Value Std.Error   t-value p-value
# (Intercept) 15.117499 1.3375482 11.302396  0.0000
# timeperiod  -0.006723 0.0216767 -0.310158  0.7571
# phi_1       -0.023049 0.0037224 -6.191767  0.0000
# phi_2       -0.023928 0.0206221 -1.160334  0.2487
# phi_3       -0.002806 0.0175760 -0.159663  0.8735
# phi_4        0.037585 0.0050339  7.466423  0.0000
#
#  Correlation:
#            (Intr) timprd phi_1  phi_2  phi_3
# timeperiod -0.989
# phi_1       0.781 -0.836
# phi_2       0.927 -0.973  0.877
# phi_3       0.931 -0.973  0.822  0.994
# phi_4       0.453 -0.314 -0.011  0.086  0.111
#
# Standardized residuals:
#        Min         Q1        Med         Q3        Max
# -8.4394705 -0.2236597  0.1162450  0.3322718  2.9095160
#
# Residual standard error: 0.02131942
# Degrees of freedom: 104 total; 98 residual
# plot without title
